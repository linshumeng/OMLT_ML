# %%
import numpy as np
from sklearn.linear_model import *
from lineartree import LinearTreeRegressor
import matplotlib.pyplot as plt
import pprint
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
pp = pprint.PrettyPrinter(indent=4)
import time
import lightgbm as lgb
import pandas as pd

# %%
# Read the data from the csv file
data = np.genfromtxt('data/PHTSV_Table_HMAX_Adjusted.csv', delimiter=',')
data = data[1:, :]

# 2 D array containing Pressure and Enthalpy data
P_H = data[:, 0:2]

# Scale the pressure to bar and scale the enthalpy to kJ/mol
P_H[:, 0] = P_H[:, 0] / 1e5
P_H[:, 1] = P_H[:, 1] / 1000
minP = np.min(data[:, 0])
maxP = np.max(data[:, 0])
minH = np.min(data[:, 1])
maxH = np.max(data[:, 1])
print(minH)
print(maxH)
print(minP)
print(maxP)

# Vector containing Temperatures
T = data[:, 2]
minT = np.min(T)
maxT = np.max(T)
# Out:
# 1.27588638
# 65.523
# 1.0
# 250.0

# %%
X_train, X_test, y_train, y_test = train_test_split(P_H, T, test_size=0.2, random_state=42)

# %% [markdown]
# # num_iterations

# %%
train_data_linear = lgb.Dataset(
    X_train, label=y_train, params={'linear_tree': True, })
lgb_dic = {}
num_iterations = np.arange(20, 110, 10)
for i in range(len(num_iterations)):
    params = {
        "objective": "regression",
        "metric": "rmse",
        "learning_rate": 0.2,
        'num_leaves': 100,
        "verbosity": -1,
        'min_samples_leaf': 8,
        'max_bin': 60,
        'num_iterations': num_iterations[i],
        'max_depth': 8,
    }
    time_start = time.time()
    model_linear = lgb.train(params, train_data_linear)
    time_end = time.time()
    print('time cost:', time_end - time_start, 's')
    y_pred_linear = model_linear.predict(X_test)
    print(
        f"Linear trees error: {round(mean_squared_error(y_test, y_pred_linear),3)}")
    df = model_linear.trees_to_dataframe()
    # len(df[df["right_child"].isnull()]) == len(
    #     df[df["left_child"].isnull()]) == len(df[df["decision_type"].isnull()])
    print('numer of leaves:', len(df[df["right_child"].isnull()]))
    lgb_dic['model' +
            str(i)] = {'time': time_end - time_start,
                       'mse': round(mean_squared_error(y_test, y_pred_linear), 3),
                       'num_leaves': len(df[df["right_child"].isnull()])}
# Out:
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.1199042797088623 s
# Linear trees error: 4.099
# numer of leaves: 2000
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.2305309772491455 s
# Linear trees error: 0.93
# numer of leaves: 3000
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.2795674800872803 s
# Linear trees error: 0.693
# numer of leaves: 4000
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.2602722644805908 s
# Linear trees error: 0.592
# numer of leaves: 4977
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.32369279861450195 s
# Linear trees error: 0.528
# numer of leaves: 5856
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.3050658702850342 s
# Linear trees error: 0.472
# numer of leaves: 6743
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.525592565536499 s
# Linear trees error: 0.448
# numer of leaves: 7590
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.49100542068481445 s
# Linear trees error: 0.422
# numer of leaves: 8499
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.3330116271972656 s
# Linear trees error: 0.397
# numer of leaves: 9314

# %%
LT_dic = {}
time_start=time.time()
regr = LinearTreeRegressor(LinearRegression(), criterion='mse', max_bins=60,
                           min_samples_leaf=8, max_depth=8, min_impurity_decrease=0.1)
regr.fit(X_train, y_train)
time_end = time.time()
LT_dic['time'] = time_end - time_start
print('time cost:', LT_dic['time'], 's')
y_pred = regr.predict(X_test)
LT_dic['mse'] = round(mean_squared_error(y_pred, y_test),3)
print(f"Linear trees error: {LT_dic['mse']}")
LT_dic['num_leaves'] = len(regr.summary(only_leaves=True))
print('numer of leaves:', LT_dic['num_leaves'])
# Out:
# time cost: 6.255917549133301 s
# Linear trees error: 0.388
# numer of leaves: 147

# %%
for i in range(len(num_iterations)):
    plt.plot(num_iterations[i], lgb_dic['model'+str(i)]['mse'], 'r*')
    if i == len(num_iterations)-1:
    #     print('last')
        plt.annotate(lgb_dic['model' + str(i)]['num_leaves'],
                    xy=(num_iterations[i], lgb_dic['model' + str(i)]['mse']), 
                    xytext=(num_iterations[i]+1, lgb_dic['model' + str(i)]['mse']-0.08), 
                    arrowprops=dict(arrowstyle="->"))
plt.axhline(y=LT_dic['mse'])
plt.annotate(str(LT_dic['num_leaves']),
             xy=(82, 0.40),
             xytext=(85, 0.45),
             arrowprops=dict(arrowstyle="- >"))
plt.ylim(0, 1)
plt.xlim(0, 110)
plt.ylabel("mse")
plt.xlabel("num_iterations")
plt.legend(labels=['LightGBM'])

# %% [markdown]
# # max_bins

# %%
max_bins = np.arange(20, 100, 10)
lgb_dic = {}
for i in range(len(max_bins)):
    train_data_linear = lgb.Dataset(
        X_train, label=y_train, params={'linear_tree': True, })
    params = {
        "objective": "regression",
        "metric": "rmse",
        "learning_rate": 0.2,
        'num_leaves': 100,
        "verbosity": -1,
        'min_samples_leaf': 8,
        'max_bin': max_bins[i],
        'num_iterations': 100,
        'max_depth': 8,
    }
    time_start = time.time()
    model_linear = lgb.train(params, train_data_linear)
    time_end = time.time()
    print('time cost:', time_end - time_start, 's')
    y_pred_linear = model_linear.predict(X_test)
    print(
        f"Linear trees error: {round(mean_squared_error(y_test, y_pred_linear),3)}")
    df = model_linear.trees_to_dataframe()
    # len(df[df["right_child"].isnull()]) == len(
    #     df[df["left_child"].isnull()]) == len(df[df["decision_type"].isnull()])
    print('numer of leaves:', len(df[df["right_child"].isnull()]))
    lgb_dic['model' +
            str(i)] = {'time': time_end - time_start, 
                        'mse': round(mean_squared_error(y_test, y_pred_linear), 3), 
                        'num_leaves': len(df[df["right_child"].isnull()])}
# Out:
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.4211270809173584 s
# Linear trees error: 5.719
# numer of leaves: 9832
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.40531229972839355 s
# Linear trees error: 1.992
# numer of leaves: 9926
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.3141517639160156 s
# Linear trees error: 1.59
# numer of leaves: 9598
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.29050588607788086 s
# Linear trees error: 1.397
# numer of leaves: 9447
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.3747227191925049 s
# Linear trees error: 0.397
# numer of leaves: 9314
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.36399102210998535 s
# Linear trees error: 0.542
# numer of leaves: 8949
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.3492882251739502 s
# Linear trees error: 0.566
# numer of leaves: 8989
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.38336658477783203 s
# Linear trees error: 0.56
# numer of leaves: 8997

# %%
LT_dic = {}
for i in range(len(max_bins)):
    time_start = time.time()
    regr = LinearTreeRegressor(LinearRegression(), criterion='mse', max_bins=max_bins[i],
                               min_samples_leaf=8, max_depth=8, min_impurity_decrease=0.1)
    regr.fit(X_train, y_train)
    time_end = time.time()
    print('time cost:', time_end - time_start, 's')
    y_pred_linear = regr.predict(X_test)
    print(
        f"Linear trees error: {round(mean_squared_error(y_test, y_pred_linear),3)}")
    print('numer of leaves:', len(regr.summary(only_leaves=True)))
    LT_dic['model' +
            str(i)] = {'time': time_end - time_start,
                       'mse': round(mean_squared_error(y_test, y_pred_linear), 3),
                       'num_leaves': len(regr.summary(only_leaves=True))}
time_start=time.time()
# Out:
# time cost: 2.5189476013183594 s
# Linear trees error: 5.431
# numer of leaves: 109
# time cost: 3.456486463546753 s
# Linear trees error: 2.969
# numer of leaves: 150
# time cost: 5.056483030319214 s
# Linear trees error: 1.049
# numer of leaves: 151
# time cost: 7.057682514190674 s
# Linear trees error: 1.498
# numer of leaves: 156
# time cost: 6.51258111000061 s
# Linear trees error: 0.388
# numer of leaves: 147
# time cost: 7.791249752044678 s
# Linear trees error: 0.942
# numer of leaves: 138
# time cost: 11.150051593780518 s
# Linear trees error: 0.572
# numer of leaves: 147
# time cost: 10.375229358673096 s
# Linear trees error: 0.374
# numer of leaves: 145

# %%
for i in range(len(max_bins)):
    plt.plot(max_bins[i], lgb_dic['model' + str(i)]['mse'], 'r*')
    plt.plot(max_bins[i], LT_dic['model' + str(i)]['mse'], 'b.')
    if i == len(max_bins) - 1:
    #     print('last')
        plt.annotate(lgb_dic['model' + str(i)]['num_leaves'],
                        xy=(max_bins[i], lgb_dic['model' + str(i)]['mse']),
                        xytext=(max_bins[i] + 1,
                                lgb_dic['model' + str(i)]['mse'] - 0.3),
                        arrowprops=dict(arrowstyle="->"))
        plt.annotate(LT_dic['model' + str(i)]['num_leaves'],
                     xy=(max_bins[i], LT_dic['model' + str(i)]['mse']),
                     xytext=(max_bins[i] - 5,
                             LT_dic['model' + str(i)]['mse'] + 0.3),
                     arrowprops=dict(arrowstyle="->"))
plt.ylim(0, 5)
plt.xlim(0, 110)
plt.ylabel("mse")
plt.xlabel("max_bins")
plt.legend(labels=['LightGBM', 'linear-tree'])

# %% [markdown]
# # max_depth

# %%
max_depth = np.arange(2, 10, 1)
lgb_dic = {}
for i in range(len(max_depth)):
    train_data_linear = lgb.Dataset(
        X_train, label=y_train, params={'linear_tree': True, })
    params = {
        "objective": "regression",
        "metric": "rmse",
        "learning_rate": 0.2,
        'num_leaves': 100,
        "verbosity": -1,
        'min_samples_leaf': 8,
        'max_bin': 60,
        'num_iterations': 100,
        'max_depth': max_depth[i],
    }
    time_start = time.time()
    model_linear = lgb.train(params, train_data_linear)
    time_end = time.time()
    print('time cost:', time_end - time_start, 's')
    y_pred_linear = model_linear.predict(X_test)
    print(
        f"Linear trees error: {round(mean_squared_error(y_test, y_pred_linear),3)}")
    df = model_linear.trees_to_dataframe()
    # len(df[df["right_child"].isnull()]) == len(
    #     df[df["left_child"].isnull()]) == len(df[df["decision_type"].isnull()])
    print('numer of leaves:', len(df[df["right_child"].isnull()]))
    lgb_dic['model' +
            str(i)] = {'time': time_end - time_start,
                       'mse': round(mean_squared_error(y_test, y_pred_linear), 3),
                       'num_leaves': len(df[df["right_child"].isnull()])}
# Out:
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.053827762603759766 s
# Linear trees error: 27.939
# numer of leaves: 400
# time cost: 0.06582331657409668 s
# Linear trees error: 7.55
# numer of leaves: 800
# time cost: 0.0887613296508789 s
# Linear trees error: 2.461
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# numer of leaves: 1553
# time cost: 0.12070274353027344 s
# Linear trees error: 1.557
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# numer of leaves: 3004
# time cost: 0.16253256797790527 s
# Linear trees error: 0.824
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# numer of leaves: 5281
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.25927734375 s
# Linear trees error: 0.544
# numer of leaves: 8113
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.29319024085998535 s
# Linear trees error: 0.397
# numer of leaves: 9314
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.3101358413696289 s
# Linear trees error: 0.368
# numer of leaves: 9866

# %%
LT_dic = {}
for i in range(len(max_depth)):
    time_start = time.time()
    regr = LinearTreeRegressor(LinearRegression(), criterion='mse', max_bins=60,
                               min_samples_leaf=8, max_depth=max_depth[i], min_impurity_decrease=0.1)
    regr.fit(X_train, y_train)
    time_end = time.time()
    print('time cost:', time_end - time_start, 's')
    y_pred_linear = regr.predict(X_test)
    print(
        f"Linear trees error: {round(mean_squared_error(y_test, y_pred_linear),3)}")
    print('numer of leaves:', len(regr.summary(only_leaves=True)))
    LT_dic['model' +
            str(i)] = {'time': time_end - time_start,
                       'mse': round(mean_squared_error(y_test, y_pred_linear), 3),
                       'num_leaves': len(regr.summary(only_leaves=True))}
time_start=time.time()
# Out:
# time cost: 1.1874303817749023 s
# Linear trees error: 442.585
# numer of leaves: 4
# time cost: 1.6553502082824707 s
# Linear trees error: 123.02
# numer of leaves: 8
# time cost: 2.939729690551758 s
# Linear trees error: 36.749
# numer of leaves: 16
# time cost: 3.899263620376587 s
# Linear trees error: 5.788
# numer of leaves: 32
# time cost: 5.340626955032349 s
# Linear trees error: 1.624
# numer of leaves: 59
# time cost: 6.7527430057525635 s
# Linear trees error: 0.719
# numer of leaves: 104
# time cost: 5.777544736862183 s
# Linear trees error: 0.388
# numer of leaves: 147
# time cost: 5.833394527435303 s
# Linear trees error: 0.37
# numer of leaves: 157

# %%
for i in range(len(max_depth)):
    plt.plot(max_depth[i], lgb_dic['model' + str(i)]['mse'], 'r*')
    plt.plot(max_depth[i], LT_dic['model' + str(i)]['mse'], 'b.')
    if i == len(max_bins) - 1:
    #     print('last')
        plt.annotate(lgb_dic['model' + str(i)]['num_leaves'],
                     xy=(max_depth[i], lgb_dic['model' + str(i)]['mse']),
                     xytext=(max_depth[i] + 1,
                                lgb_dic['model' + str(i)]['mse'] - 0.2),
                        arrowprops=dict(arrowstyle="->"))
        plt.annotate(LT_dic['model' + str(i)]['num_leaves'],
                     xy=(max_depth[i], LT_dic['model' + str(i)]['mse']),
                     xytext=(max_depth[i] - 1,
                             LT_dic['model' + str(i)]['mse'] + 0.2),
                     arrowprops=dict(arrowstyle="->"))
plt.ylim(0, 10)
plt.xlim(0, 12)
plt.ylabel("mse")
plt.xlabel("max_depth")
plt.legend(labels=['LightGBM', 'linear-tree'])

# %% [markdown]
# # prediction of optimal model

# %%
time_start = time.time()
regr = LinearTreeRegressor(LinearRegression(), criterion='mse', max_bins=60,
                           min_samples_leaf=8, max_depth=10, min_impurity_decrease=0.1)
regr.fit(X_train, y_train)
time_end = time.time()
print('time cost:', time_end, 's')
y_pred_linear = regr.predict(X_test)
print(f"Linear trees error: {round(mean_squared_error(y_test, y_pred_linear), 3)}")

print('numer of leaves:', len(regr.summary(only_leaves=True)))
# Out:
# time cost: 1677181759.5174875 s
# Linear trees error: 0.367
# numer of leaves: 159

# %%
# regr.plot_model()

# %%
regr.summary()
# Out:
# {0: {'col': 1,
#   'th': 38.26665,
#   'loss': 1572.64638,
#   'samples': 8000,
#   'children': (1, 2),
#   'models': (LinearRegression(), LinearRegression())},
#  1: {'col': 1,
#   'th': 23.34055,
#   'loss': 421.82154,
#   'samples': 4635,
#   'children': (3, 4),
#   'models': (LinearRegression(), LinearRegression())},
#  2: {'col': 1,
#   'th': 52.54379,
#   'loss': 278.60686,
#   'samples': 3365,
#   'children': (117, 118),
#   'models': (LinearRegression(), LinearRegression())},
#  3: {'col': 0,
#   'th': 21.12121,
#   'loss': 87.85061,
#   'samples': 2778,
#   'children': (5, 6),
#   'models': (LinearRegression(), LinearRegression())},
#  4: {'col': 0,
#   'th': 68.90909,
#   'loss': 177.28719,
#   'samples': 1857,
#   'children': (51, 52),
#   'models': (LinearRegression(), LinearRegression())},
#  5: {'col': 1,
#   'th': 12.30822,
#   'loss': 123.00982,
#   'samples': 251,
#   'children': (7, 8),
#   'models': (LinearRegression(), LinearRegression())},
#  6: {'col': 1,
#   'th': 18.79783,
#   'loss': 16.71461,
#   'samples': 2527,
#   'children': (27, 28),
#   'models': (LinearRegression(), LinearRegression())},
#  7: {'col': 0,
#   'th': 3.51515,
#   'loss': 28.91185,
#   'samples': 130,
#   'children': (9, 10),
#   'models': (LinearRegression(), LinearRegression())},
#  8: {'col': 0,
#   'th': 3.51515,
#   'loss': 46.38228,
#   'samples': 121,
#   'children': (15, 16),
#   'models': (LinearRegression(), LinearRegression())},
#  9: {'col': 1,
#   'th': 9.06342,
#   'loss': 13.20819,
#   'samples': 29,
#   'children': (11, 12),
#   'models': (LinearRegression(), LinearRegression())},
#  11: {'col': 1,
#   'th': 6.46757,
#   'loss': 6.11739,
#   'samples': 21,
#   'children': (13, 14),
#   'models': (LinearRegression(), LinearRegression())},
#  16: {'col': 1,
#   'th': 14.2551,
#   'loss': 13.97586,
#   'samples': 94,
#   'children': (17, 18),
#   'models': (LinearRegression(), LinearRegression())},
#  17: {'col': 0,
#   'th': 13.57576,
#   'loss': 6.75774,
#   'samples': 18,
#   'children': (19, 20),
#   'models': (LinearRegression(), LinearRegression())},
#  18: {'col': 0,
#   'th': 8.54545,
#   'loss': 3.33661,
#   'samples': 76,
#   'children': (21, 22),
#   'models': (LinearRegression(), LinearRegression())},
#  22: {'col': 1,
#   'th': 16.20198,
#   'loss': 2.14698,
#   'samples': 52,
#   'children': (23, 24),
#   'models': (LinearRegression(), LinearRegression())},
#  24: {'col': 0,
#   'th': 13.57576,
#   'loss': 0.01676,
#   'samples': 40,
#   'children': (25, 26),
#   'models': (LinearRegression(), LinearRegression())},
#  27: {'col': 1,
#   'th': 12.95718,
#   'loss': 0.54257,
#   'samples': 2032,
#   'children': (29, 30),
#   'models': (LinearRegression(), LinearRegression())},
#  28: {'col': 0,
#   'th': 56.33333,
#   'loss': 4.43853,
#   'samples': 495,
#   'children': (35, 36),
#   'models': (LinearRegression(), LinearRegression())},
#  30: {'col': 0,
#   'th': 31.18182,
#   'loss': 0.72966,
#   'samples': 667,
#   'children': (31, 32),
#   'models': (LinearRegression(), LinearRegression())},
#  31: {'col': 1,
#   'th': 16.20198,
#   'loss': 2.70637,
#   'samples': 28,
#   'children': (33, 34),
#   'models': (LinearRegression(), LinearRegression())},
#  35: {'col': 0,
#   'th': 43.75758,
#   'loss': 5.83939,
#   'samples': 76,
#   'children': (37, 38),
#   'models': (LinearRegression(), LinearRegression())},
#  36: {'col': 0,
#   'th': 68.90909,
#   'loss': 0.84341,
#   'samples': 419,
#   'children': (45, 46),
#   'models': (LinearRegression(), LinearRegression())},
#  37: {'col': 0,
#   'th': 38.72727,
#   'loss': 0.84778,
#   'samples': 49,
#   'children': (39, 40),
#   'models': (LinearRegression(), LinearRegression())},
#  38: {'col': 1,
#   'th': 20.74471,
#   'loss': 0.00644,
#   'samples': 27,
#   'children': (43, 44),
#   'models': (LinearRegression(), LinearRegression())},
#  39: {'col': 0,
#   'th': 31.18182,
#   'loss': 0.01693,
#   'samples': 37,
#   'children': (41, 42),
#   'models': (LinearRegression(), LinearRegression())},
#  45: {'col': 1,
#   'th': 22.04263,
#   'loss': 0.31216,
#   'samples': 25,
#   'children': (47, 48),
#   'models': (LinearRegression(), LinearRegression())},
#  46: {'col': 1,
#   'th': 22.04263,
#   'loss': 0.06713,
#   'samples': 394,
#   'children': (49, 50),
#   'models': (LinearRegression(), LinearRegression())},
#  51: {'col': 0,
#   'th': 13.57576,
#   'loss': 25.04214,
#   'samples': 514,
#   'children': (53, 54),
#   'models': (LinearRegression(), LinearRegression())},
#  52: {'col': 1,
#   'th': 28.53224,
#   'loss': 47.33465,
#   'samples': 1343,
#   'children': (65, 66),
#   'models': (LinearRegression(), LinearRegression())},
#  53: {'col': 0,
#   'th': 3.51515,
#   'loss': 0.9326,
#   'samples': 106,
#   'children': (55, 56),
#   'models': (LinearRegression(), LinearRegression())},
#  54: {'col': 0,
#   'th': 33.69697,
#   'loss': 0.77279,
#   'samples': 408,
#   'children': (59, 60),
#   'models': (LinearRegression(), LinearRegression())},
#  56: {'col': 0,
#   'th': 8.54545,
#   'loss': 0.0,
#   'samples': 68,
#   'children': (57, 58),
#   'models': (LinearRegression(), LinearRegression())},
#  59: {'col': 0,
#   'th': 21.12121,
#   'loss': 0.05821,
#   'samples': 145,
#   'children': (61, 62),
#   'models': (LinearRegression(), LinearRegression())},
#  60: {'col': 0,
#   'th': 48.78788,
#   'loss': 0.04111,
#   'samples': 263,
#   'children': (63, 64),
#   'models': (LinearRegression(), LinearRegression())},
#  65: {'col': 0,
#   'th': 116.69697,
#   'loss': 5.91821,
#   'samples': 476,
#   'children': (67, 68),
#   'models': (LinearRegression(), LinearRegression())},
#  66: {'col': 0,
#   'th': 174.54546,
#   'loss': 10.0896,
#   'samples': 867,
#   'children': (87, 88),
#   'models': (LinearRegression(), LinearRegression())},
#  67: {'col': 1,
#   'th': 25.28743,
#   'loss': 4.87219,
#   'samples': 125,
#   'children': (69, 70),
#   'models': (LinearRegression(), LinearRegression())},
#  68: {'col': 1,
#   'th': 27.23432,
#   'loss': 1.29615,
#   'samples': 351,
#   'children': (81, 82),
#   'models': (LinearRegression(), LinearRegression())},
#  69: {'col': 0,
#   'th': 91.54546,
#   'loss': 1.05643,
#   'samples': 47,
#   'children': (71, 72),
#   'models': (LinearRegression(), LinearRegression())},
#  70: {'col': 0,
#   'th': 99.09091,
#   'loss': 0.26986,
#   'samples': 78,
#   'children': (77, 78),
#   'models': (LinearRegression(), LinearRegression())},
#  71: {'col': 0,
#   'th': 81.48485,
#   'loss': 0.74081,
#   'samples': 23,
#   'children': (73, 74),
#   'models': (LinearRegression(), LinearRegression())},
#  72: {'col': 0,
#   'th': 99.09091,
#   'loss': 0.26937,
#   'samples': 24,
#   'children': (75, 76),
#   'models': (LinearRegression(), LinearRegression())},
#  78: {'col': 1,
#   'th': 26.58536,
#   'loss': 0.28637,
#   'samples': 31,
#   'children': (79, 80),
#   'models': (LinearRegression(), LinearRegression())},
#  81: {'col': 1,
#   'th': 25.28743,
#   'loss': 0.02877,
#   'samples': 261,
#   'children': (83, 84),
#   'models': (LinearRegression(), LinearRegression())},
#  82: {'col': 0,
#   'th': 134.30302,
#   'loss': 0.09304,
#   'samples': 90,
#   'children': (85, 86),
#   'models': (LinearRegression(), LinearRegression())},
#  87: {'col': 0,
#   'th': 116.69697,
#   'loss': 0.79538,
#   'samples': 508,
#   'children': (89, 90),
#   'models': (LinearRegression(), LinearRegression())},
#  88: {'col': 1,
#   'th': 33.07496,
#   'loss': 2.19702,
#   'samples': 359,
#   'children': (99, 100),
#   'models': (LinearRegression(), LinearRegression())},
#  89: {'col': 0,
#   'th': 91.54546,
#   'loss': 0.01835,
#   'samples': 225,
#   'children': (91, 92),
#   'models': (LinearRegression(), LinearRegression())},
#  90: {'col': 1,
#   'th': 29.83016,
#   'loss': 0.59865,
#   'samples': 283,
#   'children': (93, 94),
#   'models': (LinearRegression(), LinearRegression())},
#  93: {'col': 0,
#   'th': 154.42424,
#   'loss': 0.116,
#   'samples': 37,
#   'children': (95, 96),
#   'models': (LinearRegression(), LinearRegression())},
#  94: {'col': 0,
#   'th': 146.87878,
#   'loss': 0.02008,
#   'samples': 246,
#   'children': (97, 98),
#   'models': (LinearRegression(), LinearRegression())},
#  99: {'col': 1,
#   'th': 31.77704,
#   'loss': 0.88464,
#   'samples': 163,
#   'children': (101, 102),
#   'models': (LinearRegression(), LinearRegression())},
#  100: {'col': 0,
#   'th': 222.33333,
#   'loss': 0.31535,
#   'samples': 196,
#   'children': (109, 110),
#   'models': (LinearRegression(), LinearRegression())},
#  101: {'col': 1,
#   'th': 30.47912,
#   'loss': 0.19155,
#   'samples': 120,
#   'children': (103, 104),
#   'models': (LinearRegression(), LinearRegression())},
#  102: {'col': 0,
#   'th': 199.69698,
#   'loss': 0.03206,
#   'samples': 43,
#   'children': (107, 108),
#   'models': (LinearRegression(), LinearRegression())},
#  104: {'col': 0,
#   'th': 192.15152,
#   'loss': 0.11602,
#   'samples': 45,
#   'children': (105, 106),
#   'models': (LinearRegression(), LinearRegression())},
#  109: {'col': 0,
#   'th': 212.27272,
#   'loss': 0.06133,
#   'samples': 129,
#   'children': (111, 112),
#   'models': (LinearRegression(), LinearRegression())},
#  110: {'col': 1,
#   'th': 35.02185,
#   'loss': 0.05548,
#   'samples': 67,
#   'children': (115, 116),
#   'models': (LinearRegression(), LinearRegression())},
#  112: {'col': 1,
#   'th': 35.02185,
#   'loss': 0.01424,
#   'samples': 30,
#   'children': (113, 114),
#   'models': (LinearRegression(), LinearRegression())},
#  117: {'col': 0,
#   'th': 48.78788,
#   'loss': 121.6955,
#   'samples': 1752,
#   'children': (119, 120),
#   'models': (LinearRegression(), LinearRegression())},
#  118: {'col': 0,
#   'th': 91.54546,
#   'loss': 44.34346,
#   'samples': 1613,
#   'children': (217, 218),
#   'models': (LinearRegression(), LinearRegression())},
#  119: {'col': 0,
#   'th': 8.54545,
#   'loss': 139.70596,
#   'samples': 352,
#   'children': (121, 122),
#   'models': (LinearRegression(), LinearRegression())},
#  120: {'col': 1,
#   'th': 47.3521,
#   'loss': 25.62111,
#   'samples': 1400,
#   'children': (147, 148),
#   'models': (LinearRegression(), LinearRegression())},
#  121: {'col': 1,
#   'th': 49.29898,
#   'loss': 36.58706,
#   'samples': 65,
#   'children': (123, 124),
#   'models': (LinearRegression(), LinearRegression())},
#  122: {'col': 1,
#   'th': 50.5969,
#   'loss': 11.50347,
#   'samples': 287,
#   'children': (129, 130),
#   'models': (LinearRegression(), LinearRegression())},
#  123: {'col': 0,
#   'th': 3.51515,
#   'loss': 14.84899,
#   'samples': 49,
#   'children': (125, 126),
#   'models': (LinearRegression(), LinearRegression())},
#  125: {'col': 1,
#   'th': 44.75626,
#   'loss': 22.86577,
#   'samples': 22,
#   'children': (127, 128),
#   'models': (LinearRegression(), LinearRegression())},
#  129: {'col': 0,
#   'th': 21.12121,
#   'loss': 1.61088,
#   'samples': 245,
#   'children': (131, 132),
#   'models': (LinearRegression(), LinearRegression())},
#  130: {'col': 0,
#   'th': 26.15152,
#   'loss': 0.50006,
#   'samples': 42,
#   'children': (141, 142),
#   'models': (LinearRegression(), LinearRegression())},
#  131: {'col': 1,
#   'th': 49.29898,
#   'loss': 0.8155,
#   'samples': 73,
#   'children': (133, 134),
#   'models': (LinearRegression(), LinearRegression())},
#  132: {'col': 0,
#   'th': 33.69697,
#   'loss': 0.20425,
#   'samples': 172,
#   'children': (137, 138),
#   'models': (LinearRegression(), LinearRegression())},
#  133: {'col': 0,
#   'th': 13.57576,
#   'loss': 0.01751,
#   'samples': 65,
#   'children': (135, 136),
#   'models': (LinearRegression(), LinearRegression())},
#  137: {'col': 1,
#   'th': 49.29898,
#   'loss': 0.07552,
#   'samples': 82,
#   'children': (139, 140),
#   'models': (LinearRegression(), LinearRegression())},
#  141: {'col': 0,
#   'th': 16.09091,
#   'loss': 0.14358,
#   'samples': 18,
#   'children': (143, 144),
#   'models': (LinearRegression(), LinearRegression())},
#  142: {'col': 0,
#   'th': 38.72727,
#   'loss': 0.09879,
#   'samples': 24,
#   'children': (145, 146),
#   'models': (LinearRegression(), LinearRegression())},
#  147: {'col': 0,
#   'th': 124.24242,
#   'loss': 5.08022,
#   'samples': 902,
#   'children': (149, 150),
#   'models': (LinearRegression(), LinearRegression())},
#  148: {'col': 0,
#   'th': 136.81818,
#   'loss': 8.901,
#   'samples': 498,
#   'children': (181, 182),
#   'models': (LinearRegression(), LinearRegression())},
#  149: {'col': 0,
#   'th': 81.48485,
#   'loss': 0.16546,
#   'samples': 332,
#   'children': (151, 152),
#   'models': (LinearRegression(), LinearRegression())},
#  150: {'col': 1,
#   'th': 44.1073,
#   'loss': 1.61772,
#   'samples': 570,
#   'children': (157, 158),
#   'models': (LinearRegression(), LinearRegression())},
#  151: {'col': 0,
#   'th': 63.87879,
#   'loss': 0.01249,
#   'samples': 138,
#   'children': (153, 154),
#   'models': (LinearRegression(), LinearRegression())},
#  152: {'col': 0,
#   'th': 99.09091,
#   'loss': 0.00807,
#   'samples': 194,
#   'children': (155, 156),
#   'models': (LinearRegression(), LinearRegression())},
#  157: {'col': 0,
#   'th': 204.72728,
#   'loss': 0.52831,
#   'samples': 373,
#   'children': (159, 160),
#   'models': (LinearRegression(), LinearRegression())},
#  158: {'col': 0,
#   'th': 167.0,
#   'loss': 0.59162,
#   'samples': 197,
#   'children': (169, 170),
#   'models': (LinearRegression(), LinearRegression())},
#  159: {'col': 0,
#   'th': 159.45454,
#   'loss': 0.02898,
#   'samples': 241,
#   'children': (161, 162),
#   'models': (LinearRegression(), LinearRegression())},
#  160: {'col': 1,
#   'th': 41.51145,
#   'loss': 0.44781,
#   'samples': 132,
#   'children': (163, 164),
#   'models': (LinearRegression(), LinearRegression())},
#  163: {'col': 0,
#   'th': 222.33333,
#   'loss': 0.56485,
#   'samples': 76,
#   'children': (165, 166),
#   'models': (LinearRegression(), LinearRegression())},
#  166: {'col': 1,
#   'th': 40.6975,
#   'loss': 0.71789,
#   'samples': 47,
#   'children': (167, 168),
#   'models': (LinearRegression(), LinearRegression())},
#  169: {'col': 1,
#   'th': 46.05418,
#   'loss': 0.21909,
#   'samples': 60,
#   'children': (171, 172),
#   'models': (LinearRegression(), LinearRegression())},
#  170: {'col': 0,
#   'th': 204.72728,
#   'loss': 0.2727,
#   'samples': 137,
#   'children': (175, 176),
#   'models': (LinearRegression(), LinearRegression())},
#  172: {'col': 0,
#   'th': 149.39394,
#   'loss': 0.05101,
#   'samples': 26,
#   'children': (173, 174),
#   'models': (LinearRegression(), LinearRegression())},
#  175: {'col': 1,
#   'th': 46.05418,
#   'loss': 0.12944,
#   'samples': 60,
#   'children': (177, 178),
#   'models': (LinearRegression(), LinearRegression())},
#  177: {'col': 1,
#   'th': 44.75626,
#   'loss': 0.05934,
#   'samples': 34,
#   'children': (179, 180),
#   'models': (LinearRegression(), LinearRegression())},
#  181: {'col': 1,
#   'th': 49.29898,
#   'loss': 3.50036,
#   'samples': 209,
#   'children': (183, 184),
#   'models': (LinearRegression(), LinearRegression())},
#  182: {'col': 0,
#   'th': 184.60606,
#   'loss': 1.54423,
#   'samples': 289,
#   'children': (205, 206),
#   'models': (LinearRegression(), LinearRegression())},
#  183: {'col': 0,
#   'th': 106.63636,
#   'loss': 0.94551,
#   'samples': 86,
#   'children': (185, 186),
#   'models': (LinearRegression(), LinearRegression())},
#  184: {'col': 0,
#   'th': 91.54546,
#   'loss': 0.94567,
#   'samples': 123,
#   'children': (193, 194),
#   'models': (LinearRegression(), LinearRegression())},
#  185: {'col': 0,
#   'th': 68.90909,
#   'loss': 0.20172,
#   'samples': 54,
#   'children': (187, 188),
#   'models': (LinearRegression(), LinearRegression())},
#  186: {'col': 1,
#   'th': 48.00106,
#   'loss': 0.03978,
#   'samples': 32,
#   'children': (191, 192),
#   'models': (LinearRegression(), LinearRegression())},
#  188: {'col': 0,
#   'th': 99.09091,
#   'loss': 0.12564,
#   'samples': 33,
#   'children': (189, 190),
#   'models': (LinearRegression(), LinearRegression())},
#  193: {'col': 1,
#   'th': 50.5969,
#   'loss': 0.42038,
#   'samples': 59,
#   'children': (195, 196),
#   'models': (LinearRegression(), LinearRegression())},
#  194: {'col': 1,
#   'th': 50.5969,
#   'loss': 0.1514,
#   'samples': 64,
#   'children': (199, 200),
#   'models': (LinearRegression(), LinearRegression())},
#  196: {'col': 0,
#   'th': 68.90909,
#   'loss': 0.08797,
#   'samples': 34,
#   'children': (197, 198),
#   'models': (LinearRegression(), LinearRegression())},
#  199: {'col': 0,
#   'th': 111.66666,
#   'loss': 0.00716,
#   'samples': 27,
#   'children': (201, 202),
#   'models': (LinearRegression(), LinearRegression())},
#  200: {'col': 0,
#   'th': 111.66666,
#   'loss': 0.04078,
#   'samples': 37,
#   'children': (203, 204),
#   'models': (LinearRegression(), LinearRegression())},
#  205: {'col': 1,
#   'th': 50.5969,
#   'loss': 0.2242,
#   'samples': 125,
#   'children': (207, 208),
#   'models': (LinearRegression(), LinearRegression())},
#  206: {'col': 1,
#   'th': 50.5969,
#   'loss': 0.19646,
#   'samples': 164,
#   'children': (211, 212),
#   'models': (LinearRegression(), LinearRegression())},
#  207: {'col': 1,
#   'th': 49.29898,
#   'loss': 0.09113,
#   'samples': 78,
#   'children': (209, 210),
#   'models': (LinearRegression(), LinearRegression())},
#  211: {'col': 1,
#   'th': 49.29898,
#   'loss': 0.09922,
#   'samples': 101,
#   'children': (213, 214),
#   'models': (LinearRegression(), LinearRegression())},
#  212: {'col': 0,
#   'th': 217.30302,
#   'loss': 0.01983,
#   'samples': 63,
#   'children': (215, 216),
#   'models': (LinearRegression(), LinearRegression())},
#  217: {'col': 1,
#   'th': 57.08651,
#   'loss': 12.09673,
#   'samples': 598,
#   'children': (219, 220),
#   'models': (LinearRegression(), LinearRegression())},
#  218: {'col': 1,
#   'th': 58.38443,
#   'loss': 7.1481,
#   'samples': 1015,
#   'children': (271, 272),
#   'models': (LinearRegression(), LinearRegression())},
#  219: {'col': 0,
#   'th': 33.69697,
#   'loss': 3.88725,
#   'samples': 205,
#   'children': (221, 222),
#   'models': (LinearRegression(), LinearRegression())},
#  220: {'col': 1,
#   'th': 60.33131,
#   'loss': 2.48378,
#   'samples': 393,
#   'children': (247, 248),
#   'models': (LinearRegression(), LinearRegression())},
#  221: {'col': 0,
#   'th': 16.09091,
#   'loss': 1.11748,
#   'samples': 74,
#   'children': (223, 224),
#   'models': (LinearRegression(), LinearRegression())},
#  222: {'col': 1,
#   'th': 55.13963,
#   'loss': 1.16776,
#   'samples': 131,
#   'children': (235, 236),
#   'models': (LinearRegression(), LinearRegression())},
#  223: {'col': 0,
#   'th': 8.54545,
#   'loss': 0.36617,
#   'samples': 36,
#   'children': (225, 226),
#   'models': (LinearRegression(), LinearRegression())},
#  224: {'col': 1,
#   'th': 55.13963,
#   'loss': 0.22614,
#   'samples': 38,
#   'children': (231, 232),
#   'models': (LinearRegression(), LinearRegression())},
#  225: {'col': 0,
#   'th': 3.51515,
#   'loss': 0.09517,
#   'samples': 20,
#   'children': (227, 228),
#   'models': (LinearRegression(), LinearRegression())},
#  226: {'col': 1,
#   'th': 55.13963,
#   'loss': 0.02266,
#   'samples': 16,
#   'children': (229, 230),
#   'models': (LinearRegression(), LinearRegression())},
#  231: {'col': 1,
#   'th': 53.84171,
#   'loss': 0.06957,
#   'samples': 21,
#   'children': (233, 234),
#   'models': (LinearRegression(), LinearRegression())},
#  235: {'col': 0,
#   'th': 61.36364,
#   'loss': 0.34407,
#   'samples': 75,
#   'children': (237, 238),
#   'models': (LinearRegression(), LinearRegression())},
#  236: {'col': 0,
#   'th': 61.36364,
#   'loss': 0.12493,
#   'samples': 56,
#   'children': (243, 244),
#   'models': (LinearRegression(), LinearRegression())},
#  237: {'col': 1,
#   'th': 53.84171,
#   'loss': 0.1054,
#   'samples': 35,
#   'children': (239, 240),
#   'models': (LinearRegression(), LinearRegression())},
#  238: {'col': 1,
#   'th': 53.84171,
#   'loss': 0.05058,
#   'samples': 40,
#   'children': (241, 242),
#   'models': (LinearRegression(), LinearRegression())},
#  243: {'col': 0,
#   'th': 48.78788,
#   'loss': 0.0382,
#   'samples': 27,
#   'children': (245, 246),
#   'models': (LinearRegression(), LinearRegression())},
#  247: {'col': 0,
#   'th': 43.75758,
#   'loss': 0.6285,
#   'samples': 150,
#   'children': (249, 250),
#   'models': (LinearRegression(), LinearRegression())},
#  248: {'col': 0,
#   'th': 43.75758,
#   'loss': 0.54257,
#   'samples': 243,
#   'children': (261, 262),
#   'models': (LinearRegression(), LinearRegression())},
#  249: {'col': 0,
#   'th': 21.12121,
#   'loss': 0.17604,
#   'samples': 76,
#   'children': (251, 252),
#   'models': (LinearRegression(), LinearRegression())},
#  250: {'col': 1,
#   'th': 58.38443,
#   'loss': 0.13414,
#   'samples': 74,
#   'children': (257, 258),
#   'models': (LinearRegression(), LinearRegression())},
#  251: {'col': 1,
#   'th': 58.38443,
#   'loss': 0.04887,
#   'samples': 36,
#   'children': (253, 254),
#   'models': (LinearRegression(), LinearRegression())},
#  252: {'col': 1,
#   'th': 58.38443,
#   'loss': 0.03883,
#   'samples': 40,
#   'children': (255, 256),
#   'models': (LinearRegression(), LinearRegression())},
#  258: {'col': 0,
#   'th': 63.87879,
#   'loss': 0.04174,
#   'samples': 47,
#   'children': (259, 260),
#   'models': (LinearRegression(), LinearRegression())},
#  261: {'col': 1,
#   'th': 62.92716,
#   'loss': 0.15502,
#   'samples': 113,
#   'children': (263, 264),
#   'models': (LinearRegression(), LinearRegression())},
#  262: {'col': 1,
#   'th': 62.92716,
#   'loss': 0.13071,
#   'samples': 130,
#   'children': (267, 268),
#   'models': (LinearRegression(), LinearRegression())},
#  263: {'col': 1,
#   'th': 61.62923,
#   'loss': 0.04099,
#   'samples': 53,
#   'children': (265, 266),
#   'models': (LinearRegression(), LinearRegression())},
#  267: {'col': 1,
#   'th': 61.62923,
#   'loss': 0.03331,
#   'samples': 67,
#   'children': (269, 270),
#   'models': (LinearRegression(), LinearRegression())},
#  271: {'col': 0,
#   'th': 154.42424,
#   'loss': 3.06047,
#   'samples': 444,
#   'children': (273, 274),
#   'models': (LinearRegression(), LinearRegression())},
#  272: {'col': 1,
#   'th': 61.62923,
#   'loss': 1.77482,
#   'samples': 571,
#   'children': (299, 300),
#   'models': (LinearRegression(), LinearRegression())},
#  273: {'col': 1,
#   'th': 55.13963,
#   'loss': 0.54074,
#   'samples': 183,
#   'children': (275, 276),
#   'models': (LinearRegression(), LinearRegression())},
#  274: {'col': 1,
#   'th': 55.13963,
#   'loss': 0.59659,
#   'samples': 261,
#   'children': (289, 290),
#   'models': (LinearRegression(), LinearRegression())},
#  275: {'col': 0,
#   'th': 121.72727,
#   'loss': 0.15838,
#   'samples': 80,
#   'children': (277, 278),
#   'models': (LinearRegression(), LinearRegression())},
#  276: {'col': 0,
#   'th': 121.72727,
#   'loss': 0.19471,
#   'samples': 103,
#   'children': (283, 284),
#   'models': (LinearRegression(), LinearRegression())},
#  277: {'col': 1,
#   'th': 53.84171,
#   'loss': 0.03082,
#   'samples': 35,
#   'children': (279, 280),
#   'models': (LinearRegression(), LinearRegression())},
#  278: {'col': 1,
#   'th': 53.84171,
#   'loss': 0.01854,
#   'samples': 45,
#   'children': (281, 282),
#   'models': (LinearRegression(), LinearRegression())},
#  283: {'col': 1,
#   'th': 57.08651,
#   'loss': 0.04232,
#   'samples': 50,
#   'children': (285, 286),
#   'models': (LinearRegression(), LinearRegression())},
#  284: {'col': 1,
#   'th': 57.08651,
#   'loss': 0.03325,
#   'samples': 53,
#   'children': (287, 288),
#   'models': (LinearRegression(), LinearRegression())},
#  289: {'col': 0,
#   'th': 199.69698,
#   'loss': 0.10155,
#   'samples': 118,
#   'children': (291, 292),
#   'models': (LinearRegression(), LinearRegression())},
#  290: {'col': 0,
#   'th': 197.18182,
#   'loss': 0.19669,
#   'samples': 143,
#   'children': (293, 294),
#   'models': (LinearRegression(), LinearRegression())},
#  293: {'col': 1,
#   'th': 57.08651,
#   'loss': 0.03964,
#   'samples': 63,
#   'children': (295, 296),
#   'models': (LinearRegression(), LinearRegression())},
#  294: {'col': 1,
#   'th': 57.08651,
#   'loss': 0.03526,
#   'samples': 80,
#   'children': (297, 298),
#   'models': (LinearRegression(), LinearRegression())},
#  299: {'col': 0,
#   'th': 167.0,
#   'loss': 0.4184,
#   'samples': 258,
#   'children': (301, 302),
#   'models': (LinearRegression(), LinearRegression())},
#  300: {'col': 0,
#   'th': 161.9697,
#   'loss': 0.3405,
#   'samples': 313,
#   'children': (311, 312),
#   'models': (LinearRegression(), LinearRegression())},
#  301: {'col': 0,
#   'th': 124.24242,
#   'loss': 0.14325,
#   'samples': 118,
#   'children': (303, 304),
#   'models': (LinearRegression(), LinearRegression())},
#  302: {'col': 1,
#   'th': 59.68235,
#   'loss': 0.1027,
#   'samples': 140,
#   'children': (309, 310),
#   'models': (LinearRegression(), LinearRegression())},
#  303: {'col': 1,
#   'th': 59.68235,
#   'loss': 0.02405,
#   'samples': 46,
#   'children': (305, 306),
#   'models': (LinearRegression(), LinearRegression())},
#  304: {'col': 1,
#   'th': 59.68235,
#   'loss': 0.03221,
#   'samples': 72,
#   'children': (307, 308),
#   'models': (LinearRegression(), LinearRegression())},
#  311: {'col': 1,
#   'th': 63.57612,
#   'loss': 0.09181,
#   'samples': 146,
#   'children': (313, 314),
#   'models': (LinearRegression(), LinearRegression())},
#  312: {'col': 1,
#   'th': 63.57612,
#   'loss': 0.08172,
#   'samples': 167,
#   'children': (315, 316),
#   'models': (LinearRegression(), LinearRegression())},
#  13: {'loss': 0.00024, 'samples': 13, 'models': LinearRegression()},
#  14: {'loss': 16.05776, 'samples': 8, 'models': LinearRegression()},
#  12: {'loss': 5.99147, 'samples': 8, 'models': LinearRegression()},
#  10: {'loss': 0.04587, 'samples': 101, 'models': LinearRegression()},
#  15: {'loss': 0.0, 'samples': 27, 'models': LinearRegression()},
#  19: {'loss': 12.16376, 'samples': 10, 'models': LinearRegression()},
#  20: {'loss': 0.00021, 'samples': 8, 'models': LinearRegression()},
#  21: {'loss': 0.0, 'samples': 24, 'models': LinearRegression()},
#  23: {'loss': 7.11756, 'samples': 12, 'models': LinearRegression()},
#  25: {'loss': 0.0, 'samples': 16, 'models': LinearRegression()},
#  26: {'loss': 0.02794, 'samples': 24, 'models': LinearRegression()},
#  29: {'loss': 0.09633, 'samples': 1365, 'models': LinearRegression()},
#  33: {'loss': 0.00342, 'samples': 15, 'models': LinearRegression()},
#  34: {'loss': 5.82516, 'samples': 13, 'models': LinearRegression()},
#  32: {'loss': 0.08821, 'samples': 639, 'models': LinearRegression()},
#  41: {'loss': 0.03059, 'samples': 19, 'models': LinearRegression()},
#  42: {'loss': 0.00252, 'samples': 18, 'models': LinearRegression()},
#  40: {'loss': 2.67219, 'samples': 12, 'models': LinearRegression()},
#  43: {'loss': 0.00081, 'samples': 9, 'models': LinearRegression()},
#  44: {'loss': 0.00926, 'samples': 18, 'models': LinearRegression()},
#  47: {'loss': 0.47514, 'samples': 16, 'models': LinearRegression()},
#  48: {'loss': 0.02242, 'samples': 9, 'models': LinearRegression()},
#  49: {'loss': 0.03581, 'samples': 284, 'models': LinearRegression()},
#  50: {'loss': 0.148, 'samples': 110, 'models': LinearRegression()},
#  55: {'loss': 0.0, 'samples': 38, 'models': LinearRegression()},
#  57: {'loss': 0.0, 'samples': 32, 'models': LinearRegression()},
#  58: {'loss': 0.0, 'samples': 36, 'models': LinearRegression()},
#  61: {'loss': 0.02996, 'samples': 55, 'models': LinearRegression()},
#  62: {'loss': 0.07548, 'samples': 90, 'models': LinearRegression()},
#  63: {'loss': 0.03909, 'samples': 111, 'models': LinearRegression()},
#  64: {'loss': 0.04259, 'samples': 152, 'models': LinearRegression()},
#  73: {'loss': 0.00228, 'samples': 13, 'models': LinearRegression()},
#  74: {'loss': 1.70091, 'samples': 10, 'models': LinearRegression()},
#  75: {'loss': 0.80074, 'samples': 8, 'models': LinearRegression()},
#  76: {'loss': 0.00368, 'samples': 16, 'models': LinearRegression()},
#  77: {'loss': 0.05858, 'samples': 47, 'models': LinearRegression()},
#  79: {'loss': 0.73591, 'samples': 12, 'models': LinearRegression()},
#  80: {'loss': 0.00245, 'samples': 19, 'models': LinearRegression()},
#  83: {'loss': 0.01941, 'samples': 134, 'models': LinearRegression()},
#  84: {'loss': 0.03863, 'samples': 127, 'models': LinearRegression()},
#  85: {'loss': 0.00371, 'samples': 10, 'models': LinearRegression()},
#  86: {'loss': 0.10421, 'samples': 80, 'models': LinearRegression()},
#  91: {'loss': 0.02264, 'samples': 109, 'models': LinearRegression()},
#  92: {'loss': 0.01431, 'samples': 116, 'models': LinearRegression()},
#  95: {'loss': 0.06904, 'samples': 25, 'models': LinearRegression()},
#  96: {'loss': 0.21384, 'samples': 12, 'models': LinearRegression()},
#  97: {'loss': 0.01367, 'samples': 124, 'models': LinearRegression()},
#  98: {'loss': 0.02658, 'samples': 122, 'models': LinearRegression()},
#  103: {'loss': 0.05342, 'samples': 75, 'models': LinearRegression()},
#  105: {'loss': 0.42215, 'samples': 10, 'models': LinearRegression()},
#  106: {'loss': 0.02856, 'samples': 35, 'models': LinearRegression()},
#  107: {'loss': 0.03078, 'samples': 13, 'models': LinearRegression()},
#  108: {'loss': 0.03262, 'samples': 30, 'models': LinearRegression()},
#  111: {'loss': 0.0215, 'samples': 99, 'models': LinearRegression()},
#  113: {'loss': 0.03269, 'samples': 12, 'models': LinearRegression()},
#  114: {'loss': 0.00194, 'samples': 18, 'models': LinearRegression()},
#  115: {'loss': 0.04513, 'samples': 25, 'models': LinearRegression()},
#  116: {'loss': 0.06165, 'samples': 42, 'models': LinearRegression()},
#  127: {'loss': 0.0, 'samples': 12, 'models': LinearRegression()},
#  128: {'loss': 50.3047, 'samples': 10, 'models': LinearRegression()},
#  126: {'loss': 0.0, 'samples': 27, 'models': LinearRegression()},
#  124: {'loss': 2.02354, 'samples': 16, 'models': LinearRegression()},
#  135: {'loss': 0.0, 'samples': 26, 'models': LinearRegression()},
#  136: {'loss': 0.02919, 'samples': 39, 'models': LinearRegression()},
#  134: {'loss': 2.31233, 'samples': 8, 'models': LinearRegression()},
#  139: {'loss': 0.077, 'samples': 72, 'models': LinearRegression()},
#  140: {'loss': 0.06486, 'samples': 10, 'models': LinearRegression()},
#  138: {'loss': 0.18967, 'samples': 90, 'models': LinearRegression()},
#  143: {'loss': 0.14515, 'samples': 9, 'models': LinearRegression()},
#  144: {'loss': 0.14201, 'samples': 9, 'models': LinearRegression()},
#  145: {'loss': 0.12667, 'samples': 12, 'models': LinearRegression()},
#  146: {'loss': 0.07091, 'samples': 12, 'models': LinearRegression()},
#  153: {'loss': 0.01402, 'samples': 65, 'models': LinearRegression()},
#  154: {'loss': 0.01112, 'samples': 73, 'models': LinearRegression()},
#  155: {'loss': 0.00541, 'samples': 85, 'models': LinearRegression()},
#  156: {'loss': 0.01015, 'samples': 109, 'models': LinearRegression()},
#  161: {'loss': 0.01891, 'samples': 105, 'models': LinearRegression()},
#  162: {'loss': 0.03675, 'samples': 136, 'models': LinearRegression()},
#  165: {'loss': 0.01431, 'samples': 29, 'models': LinearRegression()},
#  167: {'loss': 1.08681, 'samples': 31, 'models': LinearRegression()},
#  168: {'loss': 0.0031, 'samples': 16, 'models': LinearRegression()},
#  164: {'loss': 0.07629, 'samples': 56, 'models': LinearRegression()},
#  171: {'loss': 0.04404, 'samples': 34, 'models': LinearRegression()},
#  173: {'loss': 0.0598, 'samples': 15, 'models': LinearRegression()},
#  174: {'loss': 0.03904, 'samples': 11, 'models': LinearRegression()},
#  179: {'loss': 0.08037, 'samples': 12, 'models': LinearRegression()},
#  180: {'loss': 0.04787, 'samples': 22, 'models': LinearRegression()},
#  178: {'loss': 0.02443, 'samples': 26, 'models': LinearRegression()},
#  176: {'loss': 0.12956, 'samples': 77, 'models': LinearRegression()},
#  187: {'loss': 0.03164, 'samples': 21, 'models': LinearRegression()},
#  189: {'loss': 0.07336, 'samples': 25, 'models': LinearRegression()},
#  190: {'loss': 0.28903, 'samples': 8, 'models': LinearRegression()},
#  191: {'loss': 0.0798, 'samples': 12, 'models': LinearRegression()},
#  192: {'loss': 0.01577, 'samples': 20, 'models': LinearRegression()},
#  195: {'loss': 0.19236, 'samples': 25, 'models': LinearRegression()},
#  197: {'loss': 0.12358, 'samples': 17, 'models': LinearRegression()},
#  198: {'loss': 0.05236, 'samples': 17, 'models': LinearRegression()},
#  201: {'loss': 0.00491, 'samples': 11, 'models': LinearRegression()},
#  202: {'loss': 0.00871, 'samples': 16, 'models': LinearRegression()},
#  203: {'loss': 0.04091, 'samples': 16, 'models': LinearRegression()},
#  204: {'loss': 0.04068, 'samples': 21, 'models': LinearRegression()},
#  209: {'loss': 0.10405, 'samples': 46, 'models': LinearRegression()},
#  210: {'loss': 0.07255, 'samples': 32, 'models': LinearRegression()},
#  208: {'loss': 0.08922, 'samples': 47, 'models': LinearRegression()},
#  213: {'loss': 0.09886, 'samples': 58, 'models': LinearRegression()},
#  214: {'loss': 0.09971, 'samples': 43, 'models': LinearRegression()},
#  215: {'loss': 0.02441, 'samples': 33, 'models': LinearRegression()},
#  216: {'loss': 0.0148, 'samples': 30, 'models': LinearRegression()},
#  227: {'loss': 0.07857, 'samples': 9, 'models': LinearRegression()},
#  228: {'loss': 0.10875, 'samples': 11, 'models': LinearRegression()},
#  229: {'loss': 0.02284, 'samples': 8, 'models': LinearRegression()},
#  230: {'loss': 0.02248, 'samples': 8, 'models': LinearRegression()},
#  233: {'loss': 0.11121, 'samples': 10, 'models': LinearRegression()},
#  234: {'loss': 0.03173, 'samples': 11, 'models': LinearRegression()},
#  232: {'loss': 0.07495, 'samples': 17, 'models': LinearRegression()},
#  239: {'loss': 0.14506, 'samples': 16, 'models': LinearRegression()},
#  240: {'loss': 0.07201, 'samples': 19, 'models': LinearRegression()},
#  241: {'loss': 0.05609, 'samples': 19, 'models': LinearRegression()},
#  242: {'loss': 0.0456, 'samples': 21, 'models': LinearRegression()},
#  245: {'loss': 0.04567, 'samples': 14, 'models': LinearRegression()},
#  246: {'loss': 0.03016, 'samples': 13, 'models': LinearRegression()},
#  244: {'loss': 0.09937, 'samples': 29, 'models': LinearRegression()},
#  253: {'loss': 0.0463, 'samples': 13, 'models': LinearRegression()},
#  254: {'loss': 0.05033, 'samples': 23, 'models': LinearRegression()},
#  255: {'loss': 0.02434, 'samples': 16, 'models': LinearRegression()},
#  256: {'loss': 0.0485, 'samples': 24, 'models': LinearRegression()},
#  257: {'loss': 0.09828, 'samples': 27, 'models': LinearRegression()},
#  259: {'loss': 0.03592, 'samples': 19, 'models': LinearRegression()},
#  260: {'loss': 0.0457, 'samples': 28, 'models': LinearRegression()},
#  265: {'loss': 0.04263, 'samples': 27, 'models': LinearRegression()},
#  266: {'loss': 0.03928, 'samples': 26, 'models': LinearRegression()},
#  264: {'loss': 0.11521, 'samples': 60, 'models': LinearRegression()},
#  269: {'loss': 0.03925, 'samples': 35, 'models': LinearRegression()},
#  270: {'loss': 0.02681, 'samples': 32, 'models': LinearRegression()},
#  268: {'loss': 0.09655, 'samples': 63, 'models': LinearRegression()},
#  279: {'loss': 0.02694, 'samples': 19, 'models': LinearRegression()},
#  280: {'loss': 0.03543, 'samples': 16, 'models': LinearRegression()},
#  281: {'loss': 0.02338, 'samples': 24, 'models': LinearRegression()},
#  282: {'loss': 0.013, 'samples': 21, 'models': LinearRegression()},
#  285: {'loss': 0.059, 'samples': 30, 'models': LinearRegression()},
#  286: {'loss': 0.0173, 'samples': 20, 'models': LinearRegression()},
#  287: {'loss': 0.0443, 'samples': 34, 'models': LinearRegression()},
#  288: {'loss': 0.01348, 'samples': 19, 'models': LinearRegression()},
#  291: {'loss': 0.11886, 'samples': 55, 'models': LinearRegression()},
#  292: {'loss': 0.08644, 'samples': 63, 'models': LinearRegression()},
#  295: {'loss': 0.05693, 'samples': 37, 'models': LinearRegression()},
#  296: {'loss': 0.01503, 'samples': 26, 'models': LinearRegression()},
#  297: {'loss': 0.04472, 'samples': 49, 'models': LinearRegression()},
#  298: {'loss': 0.02031, 'samples': 31, 'models': LinearRegression()},
#  305: {'loss': 0.01697, 'samples': 17, 'models': LinearRegression()},
#  306: {'loss': 0.0282, 'samples': 29, 'models': LinearRegression()},
#  307: {'loss': 0.02396, 'samples': 27, 'models': LinearRegression()},
#  308: {'loss': 0.03716, 'samples': 45, 'models': LinearRegression()},
#  309: {'loss': 0.0877, 'samples': 54, 'models': LinearRegression()},
#  310: {'loss': 0.11212, 'samples': 86, 'models': LinearRegression()},
#  313: {'loss': 0.1146, 'samples': 72, 'models': LinearRegression()},
#  314: {'loss': 0.06963, 'samples': 74, 'models': LinearRegression()},
#  315: {'loss': 0.10376, 'samples': 87, 'models': LinearRegression()},
#  316: {'loss': 0.05775, 'samples': 80, 'models': LinearRegression()}}

# %%
lgb_dic = {}
train_data_linear = lgb.Dataset(
    X_train, label=y_train, params={'linear_tree': True, })
params = {
    "objective": "regression",
    "metric": "rmse",
    "learning_rate": 0.2,
    'num_leaves': 100,
    "verbosity": -1,
    'min_samples_leaf': 8,
    'max_bin': 60,
    'num_iterations': 100,
    'max_depth': 10,
}
time_start = time.time()
model_linear = lgb.train(params, train_data_linear)
time_end = time.time()
print('time cost:', time_end - time_start, 's')
y_pred_linear = model_linear.predict(X_test)
print(
    f"Linear trees error: {round(mean_squared_error(y_test, y_pred_linear),3)}")
df = model_linear.trees_to_dataframe()
# len(df[df["right_child"].isnull()]) == len(
#     df[df["left_child"].isnull()]) == len(df[df["decision_type"].isnull()])
print('numer of leaves:', len(df[df["right_child"].isnull()]))
# Out:
# c:\Users\shumengl\.conda\envs\omlt\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# time cost: 0.5166172981262207 s
# Linear trees error: 0.408
# numer of leaves: 9975

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\Program Files\Graphviz\\bin'
# lgb.plot_tree(model_linear)
# for i in range(params['num_iterations']):
# p = lgb.create_tree_digraph(model_linear, params['num_iterations'] - 1)
p = lgb.create_tree_digraph(model_linear, -1)
# p

# %%
df = pd.read_csv('data/PHTSV_Table_HMAX_Adjusted.csv')
x = df['H(J/mol)'] / 1000
x = np.array(x)
x.shape = (100, 100)

y = df['P(Pa)'] / 100000
y = np.array(y)
y.shape = (100, 100)

z = df['T(K)']
z = np.array(z)
z.shape = (100, 100)

plt.contourf(x, y, z, 1000)
plt.ylabel('Pressure [bar]')
plt.xlabel('Enthalpy [kJ/mol]')
plt.colorbar(label='Temperature (K)')
plt.show()

# %%
T_hat = model_linear.predict(P_H)
T_hat.shape = (100, 100)

plt.contourf(x, y, T_hat-z, 1000)
plt.ylabel('Pressure [bar]')
plt.xlabel('Enthalpy [kJ/mol]')
plt.colorbar(label='Temperature (K)')
plt.show()
